# %% [markdown]
# # Color Isolation
#
# ### The challenge is to recreate the color isolation effect made famous in Schindler's List.
#
# Using just numpy, matplotlib and PIL, take an image and make it all grayscale, except for one color.

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
i = Image.open('up.jpeg')
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x900 at 0x7FAD1F90ACA0>

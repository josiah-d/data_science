# %% [markdown]
# #  Green Screen Challenge
#
# ### Use the green screen effect to combine two images
#
# #### You can do a google search for images, or use the bunny and shark images provided here.
#
# ### Advice:
# > Do not assume that the green is uniform. There might be subtle variations in the green values. Your algorithm should work for a range of greens.
# > Remember that when converting numpy arrays to images, you may need to convert floats to `np.uint8` in the range of 0 to 255

# %%
import numpy as np
from PIL import Image

# %%
bunny = Image.open('bunny.png')
bunny
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=852x480 at 0x7F7770D4AD00>

# %%
shark = Image.open('shark.jpeg')
shark
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F77840CCD90>

# %% [markdown]
# ## Final Result:

# %%
Image.open('combined.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x300 at 0x7F7770CF3460>

# %% [markdown]
# ## Probability & Statistics
#
# 1. **Explain the difference between $p(X | Y)$ and $p(X \cap Y).$**
#
#     ![](images/statistics/bayes_1.png)
#
#    Based on the image above: Compute $p(\text{BLUE | RED})$ and $p(\text{BLUE} \cap \text{RED})$
#
#    <br>
#
# 2. **Explain the difference between mutually exclusive and independence.**
#
#    <br>
#
# 3. **Explain what a p-value is ?**
#
#    <br>
#
# 4. **Compute the variance of the following population: `10, 12, 34, 24`**
#
#    <br>
#
# 5. **How would you prove if a coin is unfair ?**
#
#    <br>
#
# 6. **Explain what the standard error of mean is.**
#
#    <br>
#
# 7. **What is a confidence interval and what does it represent ?**
#
#    <br>
#
# 8. **How do you calculate the 95% confidence interval of a sample mean ?**
#
#    <br>
#
# 9. **Describe the 2 ways to decide the parameters for the given distribution that best fit the dataset ?**
#
#    <br>
#
# 10. **Describe the central limit theorem. As a data scientist, state a few scenarios where you cannot use the CLT.**
#
#    <br>
#
# 11. **Describe what statistical power is. Illustrate the concept with an example.**
#
#    <br>
#
# 12. **What is the difference of using the mean vs the median as a centrality measure ?**
#
#    <br>
#
# 13. **Given you have a significance level of 0.05 and you have ran 20 independent comparison (t-test) without correcting your significance level, what is your effective rate of false positive ?**

# %% [markdown]
# <br>
#
# ## Linear Regression
#
# 1. **What is linear regression ?**
#
#    <br>
#
# 2. **What are the assumptions of a linear regression model ?**
#
#    <br>
#
# 3. **What are the methods to test the assumptions ?**
#
#    <br>
#
# 4. **What are the steps one can take to correct for the violated assumptions ?**
#
#     <br>
#
# 5. **What is multicollinearity, why is a problem ?**
#
#    <br>
#
# 6. **How do we detect multicollinearity? Under what circumstances can we overlook multicollinearity ?**
#
#    <br>
#
# 7. **What is the interpretation of $\beta$ ? What does $\beta_0$ (the bias) mean ?**
#
#    <br>
#
# 8. **What is the interpretation of the p-value of $\beta$ ? What is the null and alternative hypothesis ?**
#
#    <br>
#
# 9. **Can you compare the beta coefficients in multiple linear regression? If not, what will allow us to ?**
#
#    <br>
#
# 10. **What are some causes for under-fitting ? How to avoid them ? What disadvantages do they bring ?**
#
#    <br>
#
# 11. **What are some causes for over-fitting ? How to avoid them ?**
#
#    <br>
#
# 12. **How to spot an outlier in multiple linear regression ?**
#
#    <br>
#
# 13. **What does it mean in multiple regression when a point has high levarage ? What constitutes an influential point ? Why are they important ?**
#
#     <br>
#
# 14. **How to determine how many features to select for your model ? What difference does it make if you are fitting on on a large (does not fit into memory) dataset ?**
#
#     <br>
#
# 15. **What is the cost function for linear regression ?**
#
#     <br>
#
# 16. **Using the cost function, describe two algorithms to fit a linear regression model.**
#
#    <br>
#
# 17. **What are the differences between running linear regression on a large (does not fit into memory) vs a small dataset ?**

# %% [markdown]
# <br>
#
# ## Logistic Regression
#
# **Questions for Linear Regression are applicable to Logistic Regression, except for the ones listed below.**
#
# <br>
#
# 1. **What is the difference between logistic regression and linear regression ?**
#
#    <br>
#
# 2. **How do you use logistic regression to tackle a classification problem with multiple labels ?**
#
#    <br>
#
# 3. **Interpretation of logistic regression model coefficients**
#
#    - Say $\beta_1 = -0.0621$
#    - Say $\beta_1 = 0.0621$
#    - Say $\beta_1 = 0.0621$ and feature 1 is $log_2$ transformed
#
#    <br>
#
# 4. **How to find the decision boundary in the feature space for a trained logistic regression model ? (Work through an example when regressed with 1 feature)**
#
#      <br>
#
# 5. **What is the cost function for logistic regression ?**
#
#    <br>
#
# 6. **Coefficient of features (in logistic regression) is the opposite sign of what you expect. What might be the problem ?**

# %% [markdown]
# <br>
#
# ## Regularization
#
# 1. **Why is regularization necessary ?**
#
#    <br>
#
# 2. **What are some ways to regularize a logistic regression model ?**
#
#    <br>
#
# 3. **Briefly describe the principles behind (Lasso and Ridge) regularization ? What are the differences between Lasso and Ridge regularization ?**

# %% [markdown]
# <br>
#
# ## Evaluation
#
# 1. **Explain what precision, recall and specificity are.**
#
#    <br>
#
# 2. **What are the differences between a precision-recall curve and a ROC curve ?**
#
#    <br>
#
# 3. **What is the F-score ?**
#
#    <br>
#
# 4. **You have built a logistic regression model to predict fraud, how do you decide the threshold for deciding fraud or not fraud ?**

# %% [markdown]
# <br>
#
# ## Validation
#
# 1. **How do you test a model to ensure it is robust ?**
#
#    <br>
#
# 2. **Given you have trained and tested a model with cross validation and you deploy the model and it performs significantly more poorly than in cross validation. Provide some reasonable explanations.**

# %% [markdown]
# ## Decision Tree
#
# 1. **What is entropy ?**
#
#    <br>
#
# 2. **How does decision tree work ? (For classification)**
#
#    <br>
#
# 3. **How to avoid overfitting (low bias and high variance) ?**
#
#    <br>
#
# 4. **Why is post-pruning better than max depth for avoiding over-fitting ?**

# %% [markdown]
# ## Random Forest
#
# 1. **Why is random forest perform better than decision tree ?**
#
#    <br>
#
# 2. **Why bootstrap data and sample features for each tree ?**
#
#    <br>
#
# 3. **What is out-of-bag (OOB) error ?**
#
#    <br>
#
# 4. **What is the proximity matrix and how is it computed ?**
#
#    <br>
#
# 5. **How do you use the proximity matrix to impute missing values ?**
#
#    <br>
#
# 6. **How is feature importance computed ?**
#
#    <br>
#
# 7. **What is random forest better/worse than logistic regression at ?**
